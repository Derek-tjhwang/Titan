# %%
[FSN 온라인 코딩 테스트]

- 제한시간: 45분


제한시간 내에 풀어주시고 완료 후 해당 페이지에서 퇴장(닫기 X 버튼)해 주시면 됩니다.

해당 페이지에서 풀어주시면 되며,
제한시간보다 일찍 완료 시, 가산점이 있습니다.
제한시간보다 일찍 완료 될 경우, 아래의 문제풀이를 복사하여 담당자메일로 회신 부탁드립니다.
<담당자 메일 jyc@fsn.co.kr>


1. Sorting & Binary Search 함수 구현

#include <stdio.h>
#include <assert.h>
#include <string.h>

/* Coding Test
Assignment : 다음 함수를 구현하세요

 1. sorting : 알고 있는 오름차순 정렬 알고리즘을 mysort 함수에 구현하세요
 2. binary search : 이진 검색 알고리즘을 아래의 mybsearch 함수에 구현하세요.
   
참고: 이진 검색 알고리즘(binary search algorithm)은 정렬된 리스트에서 특정한 값을 찾는 알고리즘이다. 처음 중간의 값을 임의의 값으로 선택하여, 그 값을 찾고자 하는 값과 크고 작음을 비교하는 방식을 채택하고 있다. 처음 선택한 중앙값이 만약 찾는 값보다 크면 그 값은 새로운 최고값이 되며, 작으면 그 값은 새로운 최하값이 된다.

 Unit Test를 이용하여 검증하면 추가 가산점이 있습니다.
 C 언어에 익숙하지 않을 경우, Java, PHP 등 자신 있는 언어로 작성 가능합니다.

작성 언어는 파이썬 3.5번젼을 이용하여 작성하였습니다.

*/

def mysort(a):
    n = len(a)
    
    if n <= 1:
        return
    
    mid = n // 2
    g1 = a[:mid]
    g2 = a[mid:]
    mysort(g1)
    mysort(g2)
    i1 = 0
    i2 = 0
    ia = 0
    while i1 < len(g1) and i2 < len(g2):
        if g1[i1] < g2[i2]:
            a[ia] = g1[i1]
            i1 += 1
            ia += 1
        else:
            a[ia] = g2[i2]
            i2 += 1
            ia += 1
    while i1 < len(g1):
        a[ia] = g1[i1]
        i1 += 1
        ia += 1
    
    while i2 < len(g2):
        a[ia] = g2[i2]
        i2 += 1
        ia += 1


def mybsearch(a, x):
    start = 0
    end = len(a) -1
    
    while start <= end:
        mid = (start + end) // 2
        if x == a[mid]:
            return mid
        elif x > a[mid]:
            start = mid + 1
        else:
            end = mid - 1
            
    return -1

d = [ 34, 1, 9, 2, 10, 11, 45, 100, 80 , 84 , 99 ]
mysort(d)
print(d)
print( "Found index : " + mybsearch( d, 2));

2. 함수 구현 하기

1부터 n까지 8이라는 숫자가 총 몇번 나오는 지 세는 함수를 작성하세요.
8이 포함되어 있는 숫자의 갯수를 카운팅 하는 것이 아니라 8이라는 숫자를 모두 카운팅 해야 한다.
(※ 예를들어 8808은 3, 8888은 4로 카운팅 해야 함)
(C 언어가 아닌 언어로 작성해도 무방합니다)

int count8(int n)
{
   // 1~n까지의 수에서 8이  몇번 나오는지 계산하는 함수를 작성하세요.

 
}

int main()
{
   int cnt = count8( 10000 );
   printf( "Count of 8 = %d \n", cnt );
   assert( cnt == 4000 );    

}
